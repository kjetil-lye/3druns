# %%
import sys
sys.path.append('../python')

import plot_info
import convergence
import os
import os.path

# %%
CLOUDSHOCK_DATA_PATH = plot_info.get_environment("THREEDIMS_PATH", [])

resolutions = [64, 128, 256, 512]

statistics = ["mean", "variance"]
variable = "rho"
setup = "Cloudshock"

basename = os.path.join(CLOUDSHOCK_DATA_PATH, 'cloudshock/stats/N{resolution}/cloudshock_{statistic}_1.nc')
    
convergence.plot_statistics_convergence(resolutions, basename, statistics, variable, setup)

basename_single = os.path.join(CLOUDSHOCK_DATA_PATH, 'cloudshock/stats/N{resolution}/cloudshock_1.nc')

try:
    convergence.plot_single_sample_convergence(resolutions, basename_sample, 0, variable, setup)
except:
    print("Failed plotting single sample converence")
# Out:
# Failed plotting single sample converence
